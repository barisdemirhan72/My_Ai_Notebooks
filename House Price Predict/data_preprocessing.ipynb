# %%
import os 
import numpy as np
import pandas as pd

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
# ...

# %%
df = pd.read_csv("Yeni klasör/hepsiemlak.csv")

# %%
df.head()
# Out:
#                                        img-link href  photo-count  \
# 0  https://www.hepsiemlak.com/istanbul-sariyer-ru...           24
# 1  https://www.hepsiemlak.com/istanbul-besiktas-l...           37
# 2  https://www.hepsiemlak.com/istanbul-sisli-gulb...            9
# 3  https://www.hepsiemlak.com/istanbul-kartal-cev...           26
# 4  https://www.hepsiemlak.com/istanbul-sisli-esen...           30
#
#    list-view-price list-view-date  \
# 0             50.0     04-03-2025
# 1             60.0     04-03-2025
# 2             22.0     04-03-2025
# 3             35.0     01-03-2025
# 4            285.0     04-03-2025
#
#                                      list-view-title           left  \
# 0  Sarıyer Rumelikavağı Mahallesinde Deniz Manzar...  Kiralık Daire
# 1  Zorlu Avm Yakını Birkent Sitesinde Kiralık 3+1...  Kiralık Daire
# 2                     Yeni Tadilatli Tertemiz Arakat  Kiralık Daire
# 3  Dap Adam Kule Deniz Manzaralı Eşyalı 1+1 Marma...  Kiralık Daire
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   img-link href                        48 non-null     object
#  1   photo-count                          48 non-null     int64
#  2   list-view-price                      48 non-null     float64
#  3   list-view-date                       48 non-null     object
#  4   list-view-title                      24 non-null     object
#  5   left                                 48 non-null     object
#  6   celly                                48 non-null     object
#  7   celly 2                              48 non-null     object
#  8   celly 3                              48 non-null     object
#  9   celly 4                              42 non-null     object
#  10  list-view-location                   48 non-null     object
# ...

# %%
files = os.listdir('Yeni klasör')
df = pd.concat([pd.read_csv(f"Yeni klasör/{file}") for file in files],ignore_index=True)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1942 entries, 0 to 1941
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   img-link href                        1942 non-null   object
#  1   photo-count                          1942 non-null   int64
#  2   list-view-price                      1942 non-null   object
#  3   list-view-date                       1942 non-null   object
#  4   left                                 1051 non-null   object
#  5   celly                                1942 non-null   object
#  6   celly 2                              1942 non-null   object
#  7   celly 3                              1942 non-null   object
#  8   celly 4                              1912 non-null   object
#  9   list-view-location                   1942 non-null   object
#  10  img-wrp href                         1035 non-null   object
# ...

# %%
df.head()
# Out:
#                                        img-link href  photo-count  \
# 0  https://www.hepsiemlak.com/istanbul-sariyer-ru...           24
# 1  https://www.hepsiemlak.com/istanbul-besiktas-l...           37
# 2  https://www.hepsiemlak.com/istanbul-sisli-gulb...            9
# 3  https://www.hepsiemlak.com/istanbul-kartal-cev...           26
# 4  https://www.hepsiemlak.com/istanbul-sisli-esen...           30
#
#   list-view-price list-view-date           left  \
# 0            50.0     04-03-2025  Kiralık Daire
# 1            60.0     04-03-2025  Kiralık Daire
# 2            22.0     04-03-2025  Kiralık Daire
# 3            35.0     01-03-2025  Kiralık Daire
# 4           285.0     04-03-2025  Kiralık Daire
#
#                               celly celly 2  \
# 0  4 +\n                          1  160 m²
# 1  3 +\n                          1  110 m²
# 2  2 +\n                          1   90 m²
# 3  1 +\n                          1   85 m²
# 4  3 +\n                          1  200 m²
#
# ...

# %%
help(df.drop)
# Out:
# Help on method drop in module pandas.core.frame:
#
# drop(labels: 'IndexLabel | None' = None, *, axis: 'Axis' = 0, index: 'IndexLabel | None' = None, columns: 'IndexLabel | None' = None, level: 'Level | None' = None, inplace: 'bool' = False, errors: 'IgnoreRaise' = 'raise') -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by directly specifying index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level. See the :ref:`user guide <advanced.shown_levels>`
#     for more information about the now unused levels.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop. A tuple will be used as a single
#         label and not treated as a list-like.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
# ...

# %%
df.columns
# Out:
# Index(['img-link href', 'photo-count', 'list-view-price', 'list-view-date',
#        'left', 'celly', 'celly 2', 'celly 3', 'celly 4', 'list-view-location',
#        'img-wrp href', 'he-lazy-image src',
#        'listing-card--owner-info__firm-name', 'eids-badge__description',
#        'eids-badge__label', 'he-lazy-image src 2', 'he-lazy-image src 3',
#        'list-view-header', 'list-view-title', 'img-wrp href 2',
#        'he-lazy-image src 4', 'listing-card--owner-info__name'],
#       dtype='object')

# %%
df.head()
# Out:
#                                        img-link href  photo-count  \
# 0  https://www.hepsiemlak.com/istanbul-sariyer-ru...           24
# 1  https://www.hepsiemlak.com/istanbul-besiktas-l...           37
# 2  https://www.hepsiemlak.com/istanbul-sisli-gulb...            9
# 3  https://www.hepsiemlak.com/istanbul-kartal-cev...           26
# 4  https://www.hepsiemlak.com/istanbul-sisli-esen...           30
#
#   list-view-price list-view-date           left  \
# 0            50.0     04-03-2025  Kiralık Daire
# 1            60.0     04-03-2025  Kiralık Daire
# 2            22.0     04-03-2025  Kiralık Daire
# 3            35.0     01-03-2025  Kiralık Daire
# 4           285.0     04-03-2025  Kiralık Daire
#
#                               celly celly 2  \
# 0  4 +\n                          1  160 m²
# 1  3 +\n                          1  110 m²
# 2  2 +\n                          1   90 m²
# 3  1 +\n                          1   85 m²
# 4  3 +\n                          1  200 m²
#
# ...

# %%
try:
    df.drop(['list-view-date','left','listing-card--owner-info__firm-name','eids-badge__description','eids-badge__label','he-lazy-image src 2','he-lazy-image src 3','list-view-header','list-view-title','img-wrp href 2','he-lazy-image src 4','listing-card--owner-info__name'],axis=1,inplace=True)
except Exception as e:
    print("Bir hata oluştu {e}")

# %%
df.head()
# Out:
#                                        img-link href  photo-count  \
# 0  https://www.hepsiemlak.com/istanbul-sariyer-ru...           24
# 1  https://www.hepsiemlak.com/istanbul-besiktas-l...           37
# 2  https://www.hepsiemlak.com/istanbul-sisli-gulb...            9
# 3  https://www.hepsiemlak.com/istanbul-kartal-cev...           26
# 4  https://www.hepsiemlak.com/istanbul-sisli-esen...           30
#
#   list-view-price                             celly celly 2  \
# 0            50.0  4 +\n                          1  160 m²
# 1            60.0  3 +\n                          1  110 m²
# 2            22.0  2 +\n                          1   90 m²
# 3            35.0  1 +\n                          1   85 m²
# 4           285.0  3 +\n                          1  200 m²
#
#                                celly 3  celly 4  \
# 0  49\n                        Yaşında   3. Kat
# 1  40\n                        Yaşında   3. Kat
# 2  19\n                        Yaşında   3. Kat
# ...

# %%
df.drop(['img-wrp href','photo-count','he-lazy-image src'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                                        img-link href list-view-price  \
# 0  https://www.hepsiemlak.com/istanbul-sariyer-ru...            50.0
# 1  https://www.hepsiemlak.com/istanbul-besiktas-l...            60.0
# 2  https://www.hepsiemlak.com/istanbul-sisli-gulb...            22.0
# 3  https://www.hepsiemlak.com/istanbul-kartal-cev...            35.0
# 4  https://www.hepsiemlak.com/istanbul-sisli-esen...           285.0
#
#                               celly celly 2  \
# 0  4 +\n                          1  160 m²
# 1  3 +\n                          1  110 m²
# 2  2 +\n                          1   90 m²
# 3  1 +\n                          1   85 m²
# 4  3 +\n                          1  200 m²
#
#                                celly 3  celly 4  \
# 0  49\n                        Yaşında   3. Kat
# 1  40\n                        Yaşında   3. Kat
# 2  19\n                        Yaşında   3. Kat
# 3  10\n                        Yaşında  12. Kat
# ...

# %%
df.drop(['img-link href'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   list-view-price                             celly celly 2  \
# 0            50.0  4 +\n                          1  160 m²
# 1            60.0  3 +\n                          1  110 m²
# 2            22.0  2 +\n                          1   90 m²
# 3            35.0  1 +\n                          1   85 m²
# 4           285.0  3 +\n                          1  200 m²
#
#                                celly 3  celly 4  \
# 0  49\n                        Yaşında   3. Kat
# 1  40\n                        Yaşında   3. Kat
# 2  19\n                        Yaşında   3. Kat
# 3  10\n                        Yaşında  12. Kat
# 4  14\n                        Yaşında   7. Kat
#
#                         list-view-location
# 0  İstanbul / Sarıyer / Rumeli Kavağı Mah.
# 1       İstanbul / Beşiktaş / Levazım Mah.
# 2         İstanbul / Şişli / Gülbahar Mah.
# 3         İstanbul / Kartal / Cevizli Mah.
# 4         İstanbul / Şişli / Esentepe Mah.

# %%
df['location'] = df['list-view-location'].apply(lambda x: x.split('/')[0])
df['city'] = df['location']
df['city'].head()
# Out:
# 0    İstanbul
# 1    İstanbul
# 2    İstanbul
# 3    İstanbul
# 4    İstanbul
# Name: city, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1942 entries, 0 to 1941
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   list-view-price     1942 non-null   object
#  1   celly               1942 non-null   object
#  2   celly 2             1942 non-null   object
#  3   celly 3             1942 non-null   object
#  4   celly 4             1912 non-null   object
#  5   list-view-location  1942 non-null   object
#  6   location            1942 non-null   object
#  7   city                1942 non-null   object
# dtypes: object(8)
# memory usage: 121.5+ KB

# %%
df['district'] = df['list-view-location'].apply(lambda x: x.split('/')[1])
df['district'].head()
# Out:
# 0      Sarıyer
# 1     Beşiktaş
# 2        Şişli
# 3       Kartal
# 4        Şişli
# Name: district, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1942 entries, 0 to 1941
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   list-view-price     1942 non-null   object
#  1   celly               1942 non-null   object
#  2   celly 2             1942 non-null   object
#  3   celly 3             1942 non-null   object
#  4   celly 4             1912 non-null   object
#  5   list-view-location  1942 non-null   object
#  6   location            1942 non-null   object
#  7   city                1942 non-null   object
#  8   district            1942 non-null   object
# dtypes: object(9)
# memory usage: 136.7+ KB

# %%
df['neighborhood'] = df['list-view-location'].apply(lambda x: x.split('/')[2])
df['neighborhood'].head()
# Out:
# 0     Rumeli Kavağı Mah.
# 1           Levazım Mah.
# 2          Gülbahar Mah.
# 3           Cevizli Mah.
# 4          Esentepe Mah.
# Name: neighborhood, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1942 entries, 0 to 1941
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   list-view-price     1942 non-null   object
#  1   celly               1942 non-null   object
#  2   celly 2             1942 non-null   object
#  3   celly 3             1942 non-null   object
#  4   celly 4             1912 non-null   object
#  5   list-view-location  1942 non-null   object
#  6   location            1942 non-null   object
#  7   city                1942 non-null   object
#  8   district            1942 non-null   object
#  9   neighborhood        1942 non-null   object
# dtypes: object(10)
# memory usage: 151.8+ KB

# %%
df.drop(['list-view-location','location'],axis=1,inplace=True)

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1942 entries, 0 to 1941
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   list-view-price  1942 non-null   object
#  1   celly            1942 non-null   object
#  2   celly 2          1942 non-null   object
#  3   celly 3          1942 non-null   object
#  4   celly 4          1912 non-null   object
#  5   city             1942 non-null   object
#  6   district         1942 non-null   object
#  7   neighborhood     1942 non-null   object
# dtypes: object(8)
# memory usage: 121.5+ KB
#   list-view-price                             celly celly 2  \
# 0            50.0  4 +\n                          1  160 m²
# 1            60.0  3 +\n                          1  110 m²
# 2            22.0  2 +\n                          1   90 m²
# 3            35.0  1 +\n                          1   85 m²
# ...

# %%
print(df['celly'].unique())
# Out:
# ['4 +\n                          1' '3 +\n                          1'
#  '2 +\n                          1' '1 +\n                          1'
#  '5 +\n                          1' '4 +\n                          0'
#  '4 +\n                          2' '6 +\n                          2'
#  '7 +\n                          2' '2 +\n                          2'
#  '2 +\n                          0' '5 +\n                          2'
#  'Stüdyo' '6 +\n                          1'
#  '1 +\n                          2' '2 +\n                          7'
#  '23 +\n                          1' '3 +\n                          3'
#  '3 +\n                          2' '7 +\n                          1'
#  '8 +\n                          1' '3 +\n                          0'
#  '12 +\n                          9' '3 +\n                          4'
#  '2 +\n                          10']

# %%
df['celly'] = df['celly'].apply(lambda x: x.replace('Stüdyo','1 + 0'))

# %%
df['celly'] = df['celly'].apply(lambda x: x.replace('\n',''))

# %%
df['room'] = df['celly'].apply(lambda x: x.split('+')[0]).astype(int)

# %%
df['living room'] = df['celly'].apply(lambda x: x.split('+')[1]).astype(int)

# %%
df.head()
# Out:
#   list-view-price                           celly celly 2  \
# 0            50.0  4 +                          1  160 m²
# 1            60.0  3 +                          1  110 m²
# 2            22.0  2 +                          1   90 m²
# 3            35.0  1 +                          1   85 m²
# 4           285.0  3 +                          1  200 m²
#
#                                celly 3  celly 4       city    district  \
# 0  49\n                        Yaşında   3. Kat  İstanbul     Sarıyer
# 1  40\n                        Yaşında   3. Kat  İstanbul    Beşiktaş
# 2  19\n                        Yaşında   3. Kat  İstanbul       Şişli
# 3  10\n                        Yaşında  12. Kat  İstanbul      Kartal
# 4  14\n                        Yaşında   7. Kat  İstanbul       Şişli
#
#           neighborhood  room  living room
# 0   Rumeli Kavağı Mah.     4            1
# 1         Levazım Mah.     3            1
# 2        Gülbahar Mah.     2            1
# ...

# %%
df['room'].unique()
# Out:
# array([ 4,  3,  2,  1,  5,  6,  7, 23,  8, 12])

# %%
df['living room'].unique()
# Out:
# array([ 1,  0,  2,  7,  3,  9,  4, 10])

# %%
df.drop(['celly'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1942 entries, 0 to 1941
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   list-view-price  1942 non-null   object
#  1   celly 2          1942 non-null   object
#  2   celly 3          1942 non-null   object
#  3   celly 4          1912 non-null   object
#  4   city             1942 non-null   object
#  5   district         1942 non-null   object
#  6   neighborhood     1942 non-null   object
#  7   room             1942 non-null   int32
#  8   living room      1942 non-null   int32
# dtypes: int32(2), object(7)
# memory usage: 121.5+ KB

# %%
df['celly 2'].unique()
# Out:
# array(['160 m²', '110 m²', '90 m²', '85 m²', '200 m²', '82 m²', '140 m²',
#        '180 m²', '150 m²', '385 m²', '172 m²', '4.125 m²', '230 m²',
#        '350 m²', '315 m²', '220 m²', '234 m²', '950 m²', '700 m²',
#        '120 m²', '145 m²', '70 m²', '580 m²', '400 m²', '270 m²',
#        '119 m²', '226 m²', '75 m²', '54 m²', '60 m²', '80 m²', '130 m²',
#        '95 m²', '50 m²', '57 m²', '63 m²', '46 m²', '105 m²', '133 m²',
#        '250 m²', '115 m²', '186 m²', '300 m²', '330 m²', '55 m²', '93 m²',
#        '135 m²', '25 m²', '280 m²', '175 m²', '190 m²', '366 m²',
#        '165 m²', '124 m²', '103 m²', '65 m²', '78 m²', '58 m²', '48 m²',
#        '100 m²', '125 m²', '77 m²', '102 m²', '67 m²', '195 m²', '170 m²',
#        '53 m²', '240 m²', '68 m²', '118 m²', '45 m²', '174 m²', '128 m²',
#        '88 m²', '83 m²', '112 m²', '132 m²', '218 m²', '73 m²', '108 m²',
#        '71 m²', '89 m²', '72 m²', '215 m²', '325 m²', '76 m²', '79 m²',
# ...

# %%
df['celly 2'] = df['celly 2'].apply(lambda x: x.replace('.',''))
df['area'] = df['celly 2'].apply(lambda x: x.split(' ')[0]).astype(int)

# %%
df['area'].unique()
# Out:
# array([ 160,  110,   90,   85,  200,   82,  140,  180,  150,  385,  172,
#        4125,  230,  350,  315,  220,  234,  950,  700,  120,  145,   70,
#         580,  400,  270,  119,  226,   75,   54,   60,   80,  130,   95,
#          50,   57,   63,   46,  105,  133,  250,  115,  186,  300,  330,
#          55,   93,  135,   25,  280,  175,  190,  366,  165,  124,  103,
#          65,   78,   58,   48,  100,  125,   77,  102,   67,  195,  170,
#          53,  240,   68,  118,   45,  174,  128,   88,   83,  112,  132,
#         218,   73,  108,   71,   89,   72,  215,  325,   76,   79,   74,
#          98,  127,   51,   81,   94,  208,  113,  197,  256,  114,  129,
#         117,   87,  156,   44,   56,  225,   69,  275,  155,  210,   84,
#         173,  138,   66,  107,  178,  152,   96,  163,  151,  434,  775,
#         126,  182,  380,  185,   47,  340,  285,  360,   64,  222,   40,
#         310,   62,  193, 1212,  122,  148,   86,   35,  116,   32,   20,
# ...

# %%
df.drop(['celly 2'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1942 entries, 0 to 1941
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   list-view-price  1942 non-null   object
#  1   celly 3          1942 non-null   object
#  2   celly 4          1912 non-null   object
#  3   city             1942 non-null   object
#  4   district         1942 non-null   object
#  5   neighborhood     1942 non-null   object
#  6   room             1942 non-null   int32
#  7   living room      1942 non-null   int32
#  8   area             1942 non-null   int32
# dtypes: int32(3), object(6)
# memory usage: 113.9+ KB

# %%
df['celly 3'].unique()
# Out:
# array(['49\n                        Yaşında',
#        '40\n                        Yaşında',
#        '19\n                        Yaşında',
#        '10\n                        Yaşında',
#        '14\n                        Yaşında',
#        '8\n                        Yaşında',
#        '16\n                        Yaşında',
#        '15\n                        Yaşında',
#        '30\n                        Yaşında',
#        '6\n                        Yaşında',
#        '57\n                        Yaşında',
#        '1\n                        Yaşında',
#        '56\n                        Yaşında',
#        '60\n                        Yaşında',
#        '2\n                        Yaşında', 'Sıfır Bina',
#        '18\n                        Yaşında',
#        '37\n                        Yaşında',
#        '5\n                        Yaşında',
#        '22\n                        Yaşında',
#        '26\n                        Yaşında',
# ...

# %%
df['celly 3'] = df['celly 3'].apply(lambda x: x.replace('Sıfır Bina','0 Yaşında'))
df['celly 3'] = df['celly 3'].apply(lambda x: x.replace('\n',' '))

# %%
df['age'] = df['celly 3'].apply(lambda x: x.split(' ')[0]).astype(int)

# %%
df['age'].unique()
# Out:
# array([ 49,  40,  19,  10,  14,   8,  16,  15,  30,   6,  57,   1,  56,
#         60,   2,   0,  18,  37,   5,  22,  26,  54,  12,  11,  35,   4,
#         25,  28,  27,  20,   3,  17,   9,  23,   7,  31,  21,  38,  33,
#         43,  45,  36,  24,  29,  42,  32, 100,  39,  50,  13,  80, 106,
#         34,  65,  53,  75, 352,  63,  90, 200,  47,  48,  41])

# %%
df.drop(['celly 3'],axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1942 entries, 0 to 1941
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   list-view-price  1942 non-null   object
#  1   celly 4          1912 non-null   object
#  2   city             1942 non-null   object
#  3   district         1942 non-null   object
#  4   neighborhood     1942 non-null   object
#  5   room             1942 non-null   int32
#  6   living room      1942 non-null   int32
#  7   area             1942 non-null   int32
#  8   age              1942 non-null   int32
# dtypes: int32(4), object(5)
# memory usage: 106.3+ KB

# %%
df['living room'].unique()
# Out:
# array([ 1,  0,  2,  7,  3,  9,  4, 10])

# %%
df['city'].unique()
# Out:
# array(['İstanbul ', 'Bursa '], dtype=object)

# %%
df['city'] = df['city'].str.strip()

# %%
bursa_indeksleri = df[df['city'] == 'Bursa'].index

# %%
df.drop(bursa_indeksleri,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1923 entries, 0 to 1941
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   list-view-price  1923 non-null   object
#  1   celly 4          1893 non-null   object
#  2   city             1923 non-null   object
#  3   district         1923 non-null   object
#  4   neighborhood     1923 non-null   object
#  5   room             1923 non-null   int32
#  6   living room      1923 non-null   int32
#  7   area             1923 non-null   int32
#  8   age              1923 non-null   int32
# dtypes: int32(4), object(5)
# memory usage: 120.2+ KB

# %%
df['celly 4'].unique()
# Out:
# array(['3. Kat', '12. Kat', '7. Kat', '8. Kat', 'En Üst Kat', '2. Kat',
#        '4. Kat', 'Ara Kat', nan, '1. Kat', '5. Kat', 'Bahçe Katı',
#        'Villa Katı', '18. Kat', '9. Kat', '21 ve üzeri', 'Giriş Katı',
#        'Kot 3', '6. Kat', 'Kot 1', '14. Kat', 'Yüksek Giriş', 'Zemin',
#        'Kot 2', '10. Kat', 'Çatı Katı', 'Yarı Bodrum', '11. Kat',
#        'Teras Katı', 'Bodrum ve Zemin', '15. Kat', '17. Kat', '13. Kat',
#        '16. Kat', '20. Kat', 'Bodrum', '19. Kat'], dtype=object)

# %%
replace_dict = {
    'Kot 3': '-3. Kat',
    'Kot 2': '-2. Kat',
    'Kot 1': '-1. Kat',
    'Yüksek Giriş': '1. Kat',
    'Ara Kat': '2. Kat',
    'En Üst Kat': '5. Kat',
    'Bahçe Katı': '0. Kat',
    'Yarı Bodrum': '0. Kat',
    'Bodrum': '0. Kat',
    'Çatı Katı': '5. Kat',
    'Zemin': '0. Kat',
    'Giriş Katı': '0. Kat',
    'Villa Katı': '0. Kat',
    '21 ve üzeri': '21. Kat',
    'Bodrum ve Zemin': '0. Kat',
    'Teras Katı': '5. Kat',
    'nan': '2. Kat',
}
df['celly 4'] = df['celly 4'].replace(replace_dict.keys(),replace_dict.values()).
df['celly 4'].dropna(inplace=True)

# %%
df['floor'] = df['celly 4'].apply(lambda x: x.split('.')[0]).astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 df['floor'] = df['celly 4'].apply(lambda x: x.split('.')[0]).astype(int)
#
# File c:\Users\BARIŞ\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)   4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)   4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...
